# %% [markdown]
# <a href="https://colab.research.google.com/github/maringalczerjustine/CPE-103-OOP-1-A/blob/main/Laboratory_No_2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **TASK**

# %%
SHOA= float(input(" Enter (SCORE Prelim) Hands-on Activity: "))
THOA= float(input(" Enter (TOTAL Prelim) Hands-on Activity: "))
RHOA= (SHOA/THOA)
HOA = (RHOA*50)
if HOA > 50:
  print("Invalid Input")
  sys.exit()
print("\n Hands-on Activity Grade: ",HOA)

SQ= float(input("\n Enter (SCORE Prelim) Quiz: "))
TQ= float(input(" Enter (TOTAL Prelim) Qiuz: "))
RQ= (SQ/TQ)
Q = (RQ*30)
if Q > 30:
  print("Invalid Input")
  sys.exit()
print("\n Quiz Grade: ",Q)

SAss= float(input("\n Enter (SCORE Prelim) Ass: "))
TAss= float(input(" Enter (TOTAL Prelim) Ass: "))
RAss= (SAss/TAss)
Ass = (RAss*20)
if Ass > 20:
  print("Invalid Input")
  sys.exit()
print("\n Assignment Grade: ",Ass)

PCS= (HOA+Q+Ass)
print("\n Prelim Class Standing:",PCS)

SPE= float(input("\n Enter (SCORE Prelim) Exam: "))
TPE= float(input(" Enter (TOTAL Prelim) Exam: "))
PE = (SPE/TPE)*(100)
if PE > 100:
  print("Invalid Input")
  sys.exit()
print("\n Prelim Exam Grade: ",PE)

PG= (PCS*.5)+(PE*.5)
print("\nPRELIM GRADE: ",PG)

MG= float(input("\n   Enter (MIDTERM GRADE): "))
if MG > 100:
  print("Invalid Input")
  sys.exit()
print("\nMIDTERM GRADE: ",MG)
RPG= (PG/100)
RMG = (MG/100)
FG = (RPG*.5)+(RMG*.5)

print("\nFINAL GRADE: ",FG*100)
if FG*100 >= 70:
  print("PASSED")
else:
  print("FAILED")
# Out:
#  Enter (SCORE Prelim) Hands-on Activity: 65
#  Enter (TOTAL Prelim) Hands-on Activity: 100
#
#  Hands-on Activity Grade:  32.5
#
#  Enter (SCORE Prelim) Quiz: 45
#  Enter (TOTAL Prelim) Qiuz: 60
#
#  Quiz Grade:  22.5
#
#  Enter (SCORE Prelim) Ass: 98
#  Enter (TOTAL Prelim) Ass: 100
#
#  Assignment Grade:  19.6
#
#  Prelim Class Standing: 74.6
#
#  Enter (SCORE Prelim) Exam: 68
#  Enter (TOTAL Prelim) Exam: 110
#
#  Prelim Exam Grade:  61.81818181818181
#
# PRELIM GRADE:  68.2090909090909
#
#    Enter (MIDTERM GRADE): 69
#
# MIDTERM GRADE:  69.0
#
# FINAL GRADE:  68.60454545454544
# FAILED

# %% [markdown]
# **SUPPLIMENTARY**

# %% [markdown]
# STUDENT 1

# %%
def get_grade(score, total, weight):
    grade = (score / total) * weight
    if grade > weight:
        print("Invalid Input")
        sys.exit()
    return grade

name = input("Student Name: ")
section = input("Section: ")
print("\n")

HOA = get_grade(float(input(" Enter (SCORE Prelim) Hands-on Activity: ")),
                float(input(" Enter (TOTAL Prelim) Hands-on Activity: ")), 50)
print("\n Hands-on Activity Grade:", HOA)

Q = get_grade(float(input("\n Enter (SCORE Prelim) Quiz: ")),
              float(input(" Enter (TOTAL Prelim) Quiz: ")), 30)
print("\n Quiz Grade:", Q)

Ass = get_grade(float(input("\n Enter (SCORE Prelim) Assignment: ")),
                float(input(" Enter (TOTAL Prelim) Assignment: ")), 20)
print("\n Assignment Grade:", Ass)

PCS = HOA + Q + Ass
print("\n Prelim Class Standing:", PCS)

PE = get_grade(float(input("\n Enter (SCORE Prelim) Exam: ")),
               float(input(" Enter (TOTAL Prelim) Exam: ")), 100)
print("\n Prelim Exam Grade:", PE)

PG = (PCS * 0.5) + (PE * 0.5)
print("\nPRELIM GRADE:", PG)

MG = float(input("\n  Enter (MIDTERM GRADE): "))
if MG > 100:
    print("Invalid Input")
    sys.exit()
print("\nMIDTERM GRADE:", MG)

FG = ((PG / 100) * 0.5) + ((MG / 100) * 0.5)
print("\nFINAL GRADE:", FG * 100)
print("PASSED" if FG * 100 >= 60 else "FAILED")

print("\nSUMMARY:")
print("Student Name:", name)
print("Section:", section)
print("\nPrelim Grade:", PG)
if PG >= 99 <100:
  print("Prelim Grade: 1.00")
elif PG >= 95 <98:
  print("Prelim Grade: 1.25")
elif PG >= 90 <94:
  print("Prelim Grade: 1.50")
elif PG >= 85 <89:
  print("Prelim Grade: 1.75")
elif PG >= 80 <84:
  print("Prelim Grade: 2.00")
elif PG >= 75 <79:
  print("Prelim Grade: 2.25")
elif PG >= 70 <74:
  print("Prelim Grade: 2.50")
elif PG >= 65 <69:
  print("Prelim Grade: 2.75")
elif PG >= 60 <64:
  print("Prelim Grade: 3.00")
else:
  print("Prelim Grade: FAILED")
print("\nMidterm Grade:", MG)
if MG >= 99 <100:
  print("Midterm Grade: 1.00")
elif MG >= 95 <98:
  print("Midterm Grade: 1.25")
elif MG >= 90 <94:
  print("Midterm Grade: 1.50")
elif MG >= 85 <89:
  print("Midterm Grade: 1.75")
elif MG >= 80 <84:
  print("Midterm Grade: 2.00")
elif MG >= 75 <79:
  print("Midterm Grade: 2.25")
elif MG >= 70 <74:
  print("Midterm Grade: 2.50")
elif MG >= 65 <69:
  print("Midterm Grade: 2.75")
elif MG >= 60 <64:
  print("Midterm Grade: 3.00")
else:
  print("Midterm Grade: FAILED")
F = FG * 100
print("\nFinal Grade:", F)
if F >= 99 <100:
  print("Final Grade: 1.00")
elif F >= 95 <98:
  print("Final Grade: 1.25")
elif F >= 90 <94:
  print("Final Grade: 1.50")
elif F >= 85 <89:
  print("Final Grade: 1.75")
elif F >= 80 <84:
  print("Final Grade: 2.00")
elif F >= 75 <79:
  print("Final Grade: 2.25")
elif F >= 70 <74:
  print("Final Grade: 2.50")
elif F >= 65 <69:
  print("Final Grade: 2.75")
elif F >= 60 <64:
  print("Final Grade: 3.00")
else:
  print("Final Grade: FAILED")
# Out:
# Student Name: MARINGAL
# Section: BSCPE 1A
#
#
#  Enter (SCORE Prelim) Hands-on Activity: 87
#  Enter (TOTAL Prelim) Hands-on Activity: 90
#
#  Hands-on Activity Grade: 48.333333333333336
#
#  Enter (SCORE Prelim) Quiz: 45
#  Enter (TOTAL Prelim) Quiz: 45
#
#  Quiz Grade: 30.0
#
#  Enter (SCORE Prelim) Assignment: 96
#  Enter (TOTAL Prelim) Assignment: 110
#
#  Assignment Grade: 17.454545454545453
#
#  Prelim Class Standing: 95.7878787878788
#
#  Enter (SCORE Prelim) Exam: 97
#  Enter (TOTAL Prelim) Exam: 100
#
#  Prelim Exam Grade: 97.0
#
# PRELIM GRADE: 96.3939393939394
#
#   Enter (MIDTERM GRADE): 95.7
#
# MIDTERM GRADE: 95.7
#
# FINAL GRADE: 96.04696969696971
# PASSED
#
# SUMMARY:
# Student Name: MARINGAL
# Section: BSCPE 1A
#
# Prelim Grade: 96.3939393939394
# Prelim Grade: 1.25
#
# Midterm Grade: 95.7
# Midterm Grade: 1.25
#
# Final Grade: 96.04696969696971
# Final Grade: 1.25

# %% [markdown]
# STUDENT 2

# %%
def get_grade(score, total, weight):
    grade = (score / total) * weight
    if grade > weight:
        print("Invalid Input")
        sys.exit()
    return grade

name = input("Student Name: ")
section = input("Section: ")
print("\n")

HOA = get_grade(float(input(" Enter (SCORE Prelim) Hands-on Activity: ")),
                float(input(" Enter (TOTAL Prelim) Hands-on Activity: ")), 50)
print("\n Hands-on Activity Grade:", HOA)

Q = get_grade(float(input("\n Enter (SCORE Prelim) Quiz: ")),
              float(input(" Enter (TOTAL Prelim) Quiz: ")), 30)
print("\n Quiz Grade:", Q)

Ass = get_grade(float(input("\n Enter (SCORE Prelim) Assignment: ")),
                float(input(" Enter (TOTAL Prelim) Assignment: ")), 20)
print("\n Assignment Grade:", Ass)

PCS = HOA + Q + Ass
print("\n Prelim Class Standing:", PCS)

PE = get_grade(float(input("\n Enter (SCORE Prelim) Exam: ")),
               float(input(" Enter (TOTAL Prelim) Exam: ")), 100)
print("\n Prelim Exam Grade:", PE)

PG = (PCS * 0.5) + (PE * 0.5)
print("\nPRELIM GRADE:", PG)

MG = float(input("\n  Enter (MIDTERM GRADE): "))
if MG > 100:
    print("Invalid Input")
    sys.exit()
print("\nMIDTERM GRADE:", MG)

FG = ((PG / 100) * 0.5) + ((MG / 100) * 0.5)
print("\nFINAL GRADE:", FG * 100)
print("PASSED" if FG * 100 >= 60 else "FAILED")

print("\nSUMMARY:")
print("Student Name:", name)
print("Section:", section)
print("\nPrelim Grade:", PG)
if PG >= 99 <100:
  print("Prelim Grade: 1.00")
elif PG >= 95 <98:
  print("Prelim Grade: 1.25")
elif PG >= 90 <94:
  print("Prelim Grade: 1.50")
elif PG >= 85 <89:
  print("Prelim Grade: 1.75")
elif PG >= 80 <84:
  print("Prelim Grade: 2.00")
elif PG >= 75 <79:
  print("Prelim Grade: 2.25")
elif PG >= 70 <74:
  print("Prelim Grade: 2.50")
elif PG >= 65 <69:
  print("Prelim Grade: 2.75")
elif PG >= 60 <64:
  print("Prelim Grade: 3.00")
else:
  print("Prelim Grade: FAILED")
print("\nMidterm Grade:", MG)
if MG >= 99 <100:
  print("Midterm Grade: 1.00")
elif MG >= 95 <98:
  print("Midterm Grade: 1.25")
elif MG >= 90 <94:
  print("Midterm Grade: 1.50")
elif MG >= 85 <89:
  print("Midterm Grade: 1.75")
elif MG >= 80 <84:
  print("Midterm Grade: 2.00")
elif MG >= 75 <79:
  print("Midterm Grade: 2.25")
elif MG >= 70 <74:
  print("Midterm Grade: 2.50")
elif MG >= 65 <69:
  print("Midterm Grade: 2.75")
elif MG >= 60 <64:
  print("Midterm Grade: 3.00")
else:
  print("Midterm Grade: FAILED")
F = FG * 100
print("\nFinal Grade:", F)
if F >= 99 <100:
  print("Final Grade: 1.00")
elif F >= 95 <98:
  print("Final Grade: 1.25")
elif F >= 90 <94:
  print("Final Grade: 1.50")
elif F >= 85 <89:
  print("Final Grade: 1.75")
elif F >= 80 <84:
  print("Final Grade: 2.00")
elif F >= 75 <79:
  print("Final Grade: 2.25")
elif F >= 70 <74:
  print("Final Grade: 2.50")
elif F >= 65 <69:
  print("Final Grade: 2.75")
elif F >= 60 <64:
  print("Final Grade: 3.00")
else:
  print("Final Grade: FAILED")
# Out:
# Student Name: JOHNFIL
# Section: IE 1A
#
#
#  Enter (SCORE Prelim) Hands-on Activity: 78
#  Enter (TOTAL Prelim) Hands-on Activity: 90
#
#  Hands-on Activity Grade: 43.333333333333336
#
#  Enter (SCORE Prelim) Quiz: 37
#  Enter (TOTAL Prelim) Quiz: 45
#
#  Quiz Grade: 24.666666666666664
#
#  Enter (SCORE Prelim) Assignment: 97
#  Enter (TOTAL Prelim) Assignment: 110
#
#  Assignment Grade: 17.636363636363637
#
#  Prelim Class Standing: 85.63636363636364
#
#  Enter (SCORE Prelim) Exam: 88
#  Enter (TOTAL Prelim) Exam: 100
#
#  Prelim Exam Grade: 88.0
#
# PRELIM GRADE: 86.81818181818181
#
#   Enter (MIDTERM GRADE): 92.3
#
# MIDTERM GRADE: 92.3
#
# FINAL GRADE: 89.55909090909091
# PASSED
#
# SUMMARY:
# Student Name: JOHNFIL
# Section: IE 1A
#
# Prelim Grade: 86.81818181818181
# Prelim Grade: 1.75
#
# Midterm Grade: 92.3
# Midterm Grade: 1.50
#
# Final Grade: 89.55909090909091
# Final Grade: 1.75

# %% [markdown]
# STUDENT 3

# %%
def get_grade(score, total, weight):
    grade = (score / total) * weight
    if grade > weight:
        print("Invalid Input")
        sys.exit()
    return grade

name = input("Student Name: ")
section = input("Section: ")
print("\n")

HOA = get_grade(float(input(" Enter (SCORE Prelim) Hands-on Activity: ")),
                float(input(" Enter (TOTAL Prelim) Hands-on Activity: ")), 50)
print("\n Hands-on Activity Grade:", HOA)

Q = get_grade(float(input("\n Enter (SCORE Prelim) Quiz: ")),
              float(input(" Enter (TOTAL Prelim) Quiz: ")), 30)
print("\n Quiz Grade:", Q)

Ass = get_grade(float(input("\n Enter (SCORE Prelim) Assignment: ")),
                float(input(" Enter (TOTAL Prelim) Assignment: ")), 20)
print("\n Assignment Grade:", Ass)

PCS = HOA + Q + Ass
print("\n Prelim Class Standing:", PCS)

PE = get_grade(float(input("\n Enter (SCORE Prelim) Exam: ")),
               float(input(" Enter (TOTAL Prelim) Exam: ")), 100)
print("\n Prelim Exam Grade:", PE)

PG = (PCS * 0.5) + (PE * 0.5)
print("\nPRELIM GRADE:", PG)

MG = float(input("\n  Enter (MIDTERM GRADE): "))
if MG > 100:
    print("Invalid Input")
    sys.exit()
print("\nMIDTERM GRADE:", MG)

FG = ((PG / 100) * 0.5) + ((MG / 100) * 0.5)
print("\nFINAL GRADE:", FG * 100)
print("PASSED" if FG * 100 >= 60 else "FAILED")

print("\nSUMMARY:")
print("Student Name:", name)
print("Section:", section)
print("\nPrelim Grade:", PG)
if PG >= 99 <100:
  print("Prelim Grade: 1.00")
elif PG >= 95 <98:
  print("Prelim Grade: 1.25")
elif PG >= 90 <94:
  print("Prelim Grade: 1.50")
elif PG >= 85 <89:
  print("Prelim Grade: 1.75")
elif PG >= 80 <84:
  print("Prelim Grade: 2.00")
elif PG >= 75 <79:
  print("Prelim Grade: 2.25")
elif PG >= 70 <74:
  print("Prelim Grade: 2.50")
elif PG >= 65 <69:
  print("Prelim Grade: 2.75")
elif PG >= 60 <64:
  print("Prelim Grade: 3.00")
else:
  print("Prelim Grade: FAILED")
print("\nMidterm Grade:", MG)
if MG >= 99 <100:
  print("Midterm Grade: 1.00")
elif MG >= 95 <98:
  print("Midterm Grade: 1.25")
elif MG >= 90 <94:
  print("Midterm Grade: 1.50")
elif MG >= 85 <89:
  print("Midterm Grade: 1.75")
elif MG >= 80 <84:
  print("Midterm Grade: 2.00")
elif MG >= 75 <79:
  print("Midterm Grade: 2.25")
elif MG >= 70 <74:
  print("Midterm Grade: 2.50")
elif MG >= 65 <69:
  print("Midterm Grade: 2.75")
elif MG >= 60 <64:
  print("Midterm Grade: 3.00")
else:
  print("Midterm Grade: FAILED")
F = FG * 100
print("\nFinal Grade:", F)
if F >= 99 <100:
  print("Final Grade: 1.00")
elif F >= 95 <98:
  print("Final Grade: 1.25")
elif F >= 90 <94:
  print("Final Grade: 1.50")
elif F >= 85 <89:
  print("Final Grade: 1.75")
elif F >= 80 <84:
  print("Final Grade: 2.00")
elif F >= 75 <79:
  print("Final Grade: 2.25")
elif F >= 70 <74:
  print("Final Grade: 2.50")
elif F >= 65 <69:
  print("Final Grade: 2.75")
elif F >= 60 <64:
  print("Final Grade: 3.00")
else:
  print("Final Grade: FAILED")
# Out:
# Student Name: AUSTRIA
# Section: CpE 1A
#
#
#  Enter (SCORE Prelim) Hands-on Activity: 67
#  Enter (TOTAL Prelim) Hands-on Activity: 90
#
#  Hands-on Activity Grade: 37.22222222222222
#
#  Enter (SCORE Prelim) Quiz: 29
#  Enter (TOTAL Prelim) Quiz: 45
#
#  Quiz Grade: 19.333333333333336
#
#  Enter (SCORE Prelim) Assignment: 78
#  Enter (TOTAL Prelim) Assignment: 110
#
#  Assignment Grade: 14.181818181818182
#
#  Prelim Class Standing: 70.73737373737374
#
#  Enter (SCORE Prelim) Exam: 56
#  Enter (TOTAL Prelim) Exam: 100
#
#  Prelim Exam Grade: 56.00000000000001
#
# PRELIM GRADE: 63.36868686868688
#
#   Enter (MIDTERM GRADE): 75.7
#
# MIDTERM GRADE: 75.7
#
# FINAL GRADE: 69.53434343434344
# PASSED
#
# SUMMARY:
# Student Name: AUSTRIA
# Section: CpE 1A
#
# Prelim Grade: 63.36868686868688
# Prelim Grade: 3.00
#
# Midterm Grade: 75.7
# Midterm Grade: 2.25
#
# Final Grade: 69.53434343434344
# Final Grade: 2.75
